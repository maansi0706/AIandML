# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img=plt.imread("lion.jpg")
print(img.shape)
# Out:
# (480, 640, 3)

# %%
plt.imshow(img)

# %%
plt.imshow(img[:,:,0])

# %%
plt.imshow(img[:,:,0],cmap='gray')

# %%
plt.imshow(img[:,0:600])

# %%
plt.imshow(img[350:500,300:600,:])

# %%
plt.imshow(img[350:500,300:600,0])
